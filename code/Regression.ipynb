# %%
import pandas as pd
dataset=pd.read_csv('stanford_1kip_y.csv')
from pycaret.regression import *
exp = setup(data = dataset, target = 'BMI', session_id=123, normalize=True)
best = compare_models(sort = 'RMSE') #et	Extra Trees Regressor	2.5381	12.0136	3.4404	0.5327	0.1219	0.0988	0.9660
# Out:
# <style  type="text/css" >
#     #T_b657df8c_e5f5_11ec_9f70_4c327594113b th {
#           text-align: left;
# ...

# %%
et = create_model('et', return_train_score = True)
tuned_et, tuner = tune_model(et, optimize = 'RMSE',choose_better = True,return_tuner=True)#
print(tuner)
print(et)
print(tuned_et)
# Out:
# <style  type="text/css" >
# #T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col0,#T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col1,#T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col2,#T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col3,#T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col4,#T_deb4f3c2_e5f5_11ec_996a_4c327594113brow10_col5{
#             background:  yellow;
# ...

# %%
#polynomial_features = True,polynomial_degree=3
s = setup(data=dataset, target = 'BMI', normalize=True,session_id=123,feature_selection = True,
          feature_selection_threshold=0.1,remove_outliers = True,polynomial_features=True,polynomial_degree=2
)
#X_train=get_config('X_train')
#print(np.shape(X_train))
#print(X_train)
lr=create_model('lr')
# Out:
# <style  type="text/css" >
# #T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col0,#T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col1,#T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col2,#T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col3,#T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col4,#T_5d1bd198_e5fa_11ec_a8e3_4c327594113brow10_col5{
#             background:  yellow;
# ...

# %%
s = setup(data=dataset, target = 'BMI', normalize=True,session_id=123,feature_selection = True,
          feature_selection_threshold=0.018,remove_outliers = True, polynomial_features = True,polynomial_degree=3
)
#X_train=get_config('X_train')
#print(np.shape(X_train))
#print(X_train)
et=create_model('et')
# Out:
# <style  type="text/css" >
# #T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col0,#T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col1,#T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col2,#T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col3,#T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col4,#T_ca3e56e2_e5f8_11ec_8598_4c327594113brow10_col5{
#             background:  yellow;
# ...
